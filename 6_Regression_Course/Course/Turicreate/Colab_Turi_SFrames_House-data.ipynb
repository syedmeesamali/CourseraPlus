# %% [markdown]
# # Fire up Turi Create
#
# We always start with this line before using any part of Turi Create

# %%
from google.colab import drive
drive.mount('/content/MyDrive/')
# Out:
# Drive already mounted at /content/MyDrive/; to attempt to forcibly remount, call drive.mount("/content/MyDrive/", force_remount=True).

# %%
#!pip install turicreate
#!pip install turicreate
import turicreate

# %%
#!7z x '/content/MyDrive/MyDrive/Work/people_wiki.sframe.zip'
#!7z x '/content/MyDrive/MyDrive/Work/home_data.sframe.zip'
sf = turicreate.SFrame('/content/MyDrive/MyDrive/Work/home_data.sframe')

# %% [markdown]
# # SFrame basics

# %%
sf #we can view first few lines of table
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# ...

# %%
sf.tail()  # view end of the table
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 10
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7852140040 | 2014-08-25 00:00:00+00:00 |  507250.0 |   3.0    |    2.5    |
# | 9834201367 | 2015-01-26 00:00:00+00:00 |  429000.0 |   3.0    |    2.0    |
# | 3448900210 | 2014-10-14 00:00:00+00:00 |  610685.0 |   4.0    |    2.5    |
# | 7936000429 | 2015-03-26 00:00:00+00:00 | 1007500.0 |   4.0    |    3.5    |
# ...

# %% [markdown]
# # Turi Create visualization

# %%
sf.export_csv('/content/MyDrive/MyDrive/Work/people_work/house-data.csv')
