# %% [markdown]
# ## Workbook to explore House-data CSV

# %%
import pandas as pd
import numpy as np
house = pd.read_csv('./house-data.csv')     # Load the house data
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0    5650.0     1.0           0     0  ...      7        1180              0
# 1    7242.0     2.0           0     0  ...      7        2170            400
# 2   10000.0     1.0           0     0  ...      6         770              0
# 3    5000.0     1.0           0     0  ...      7        1050            910
# 4    8080.0     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
house.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
house['price'].tail(5)
# Out:
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, dtype: float64

# %%
house['price'][21612]       #Particular index
# Out:
# 325000.0

# %%
house[['price', 'sqft_living']].head(5)     #Two desired columns
# Out:
#       price  sqft_living
# 0  221900.0         1180
# 1  538000.0         2570
# 2  180000.0          770
# 3  604000.0         1960
# 4  510000.0         1680

# %%
total_area = house.sqft_living.sum()
total_price = house.price.sum()
avg_total_price = total_price / total_area
print(avg_total_price)
# Out:
# 259.6702775370998

# %%
house.floors.value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
avg_zip_98199 = house[house.zipcode == 98199][['price']].mean()
print(avg_zip_98199)
# Out:
# price    791820.807571
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(house, x="zipcode", y="price")
# Out:
# <Axes: xlabel='zipcode', ylabel='price'>

# %%
sns.boxplot(house['zipcode'], color = 'red')
# Out:
# <Axes: >

# %%
corr = house.corr(method = 'pearson')
corr
# Out:
# C:\Users\syedm\AppData\Local\Temp\ipykernel_1696\39955378.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = house.corr(method = 'pearson')
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# ...

# %%
sns.heatmap(corr, annot = True)
# Out:
# <Axes: >

# %%
area_filter = house[(house.sqft_living > 2000) & (house.sqft_living < 4000)]
area_filter
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 15     9297300055  20150124T000000   650000.0         4       3.00
# 21     2524049179  20140826T000000  2000000.0         3       2.75
# 22     7137970340  20140703T000000   285000.0         5       2.50
# ...           ...              ...        ...       ...        ...
# 21599  7202300110  20140915T000000   810000.0         4       3.00
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570    7242.0     2.0           0     0  ...      7
# ...
