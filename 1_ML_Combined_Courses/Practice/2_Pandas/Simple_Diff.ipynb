# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return x**2

# %%
# compute f(x) = x^2 for x=-10 to x=10
x = np.linspace(-10, 10, 500)
y = f(x)

#Plot f(x) on left of fig
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(121)
ax.plot(x, y)
ax.set_title("y = f(x)")

# f'(x) using the rate of change
delta_x = 0.0001
y1 = (f(x + delta_x) - f(x)) / delta_x
y2 = 2 * x
ax = fig.add_subplot(122)
ax.plot(x, y1, c="r", alpha=0.5, label="rate")
ax.plot(x, y2, c="g", alpha=0.5, label="rate")
ax.set_title("y = f'(x)")
ax.legend('Main')
plt.show()

# %%
def f2(x):
    return x**3 - 2*x**2 + 1

# compute f(x) =  for x=-10 to x=10
x = np.linspace(-10, 10, 500)
y = f2(x)

#Plot f(x) on left of fig
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(121)
ax.plot(x, y)
ax.set_title("y = f2(x)")

# f'(x) using the rate of change
delta_x = 0.0001
y1 = (f2(x + delta_x) - f2(x)) / delta_x
y2 = 3*x**2 - 4*x
ax = fig.add_subplot(122)
ax.plot(x, y1, c="r", alpha=0.5, label="rate")
ax.plot(x, y2, c="g", alpha=0.5, label="rate")
ax.set_title("y = f'(x)")
ax.legend('Main')
plt.show()
