# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('./boston_crime_21.csv')
dataset.head()
# Out:
#    INCIDENT_NUMBER  OFFENSE_CODE              OFFENSE_DESCRIPTION DISTRICT  \
# 0        312030979          3201         PROPERTY - LOST/ MISSING      E13
# 1        292152228          3301                   VERBAL DISPUTE      C11
# 2        282080177          3801             M/V ACCIDENT - OTHER       A1
# 3        222000453           617      LARCENY THEFT FROM BUILDING      E13
# 4        222000599          1106  FRAUD - CREDIT CARD / ATM FRAUD       B2
#
#    SHOOTING  OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 0         0  22/03/2021 00:00  2021      3      Monday     0
# 1         0  28/07/2021 20:45  2021      7   Wednesday    20
# 2         0  02/11/2021 13:23  2021     11     Tuesday    13
# 3         0  30/12/2021 12:30  2021     12    Thursday    12
# 4         0  29/12/2021 22:40  2021     12   Wednesday    22
#
#                                               STREET
# 0                                      BLUE HILL AVE
# 1                                            LYON ST
# 2  CAMBRIDGE ST & BOWDOIN ST\nBOSTON  MA 02114\nU...
# 3                                      MONTEBELLO RD
# 4                                      WASHINGTON ST

# %%
dataset.nunique()

# %%
dataset.describe()
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE      SHOOTING     YEAR         MONTH  \
# count     7.171700e+04  71717.000000  71717.000000  71717.0  71717.000000
# mean      2.120300e+08   2431.020455      0.012661   2021.0      6.689753
# std       2.005891e+06   1183.731769      0.111807      0.0      3.338601
# min       1.063722e+07    111.000000      0.000000   2021.0      1.000000
# 25%       2.120238e+08   1106.000000      0.000000   2021.0      4.000000
# 50%       2.120477e+08   3005.000000      0.000000   2021.0      7.000000
# 75%       2.120715e+08   3207.000000      0.000000   2021.0     10.000000
# max       3.120310e+08   3831.000000      1.000000   2021.0     12.000000
#
#                HOUR
# count  71717.000000
# mean      12.803129
# std        6.365549
# min        0.000000
# 25%        9.000000
# 50%       14.000000
# 75%       18.000000
# max       23.000000

# %%
X = dataset.drop(columns=['OFFENSE_DESCRIPTION','STREET', 'DAY_OF_WEEK', 'DISTRICT'])
y = dataset['MONTH']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 2)
